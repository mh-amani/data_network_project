# %%
import threading
import socket
import time
import pickle
from class_network import *


network = Network(4,2,[(1,1),(2,1),(1,2),(2,2)])
network.init_network()

network.add_user(0,[(0,0),(0,2)],[0.5],[0.1,0.8,0.5,0.5])
network.add_user(1,[(3,0),(3,2)],[1],0)
network.add_user(2,[(1,0),(0,1),(3,2)],[0.5,2],[0.1,0.7,0.3,0.4])
network.connection_request(0,1,'1.txt')
network.connection_request(2,3,'2.txt')

network.run()
# Out:
# Exception in thread Exception in thread Thread-220Thread-223Exception in thread Exception in thread Thread-231:
# :
# Traceback (most recent call last):
# Exception in thread Thread-233Exception in thread :
# Thread-232Exception in thread :
# Exception in thread Thread-234  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-237:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Thread-227Traceback (most recent call last):
# Exception in thread Thread-226  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# :
# :
# Thread-236Traceback (most recent call last):
# :
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Exception in thread Traceback (most recent call last):
# Exception in thread Thread-229Thread-228Exception in thread :
# :
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-240Traceback (most recent call last):
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-250Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Exception in thread Exception in thread   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-249Exception in thread :
# Thread-243:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Thread-251:
# :
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# :
# Exception in thread   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Traceback (most recent call last):
#       File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Traceback (most recent call last):
# Thread-257Exception in thread         :
# :
# Exception in thread :
# self.run()    Traceback (most recent call last):
# Thread-230self.run()Thread-242Exception in thread self.run()    :
# Traceback (most recent call last):
# Thread-256Traceback (most recent call last):
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
# self.run()  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# self.run()
#
# Traceback (most recent call last):
# Exception in thread
# Exception in thread   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# Thread-258      File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# self.run()self.run()Traceback (most recent call last):
# :
#
# Thread-252  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# self.run()  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
#
#       File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# self.run()
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#       File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# self.run()  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# :
# Traceback (most recent call last):
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Traceback (most recent call last):
#
# Exception in thread
# self.run()self.run()
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#         self.run()self._target(*self._args, **self._kwargs)
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 35, in l_sgw
#     Exception in thread
# self._target(*self._args, **self._kwargs)self.run()  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# :
#
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#         self.run()
#         self.run()self._target(*self._args, **self._kwargs)Exception in thread Thread-260self.run()Thread-259  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# Thread-253Exception in thread
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)  File "/Users/mhamani/Desktop/network_project/class_sgw.py", line 80, in l_enodb
# Traceback (most recent call last):
#
#
#   File "/Users/mhamani/Desktop/network_project/class_sgw.py", line 80, in l_enodb
#   File "/Users/mhamani/Desktop/network_project/class_mme.py", line 34, in l_enodb
#
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# :
# Traceback (most recent call last):
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-244    :
#     self.run():
# self.run()
#
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#
#
# NameErrorException in thread   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# :
# self.run()
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# Thread-245Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# self._target(*self._args, **self._kwargs)        self._target(*self._args, **self._kwargs)self.run()self.run()  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     :
#       File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
# self._target(*self._args, **self._kwargs)    :
#
# self._target(*self._args, **self._kwargs)
#   File "/Users/mhamani/Desktop/network_project/class_mme.py", line 34, in l_enodb
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# Traceback (most recent call last):
# Exception in thread self._target(*self._args, **self._kwargs)
#
#     name 'socket' is not defined
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 35, in l_sgw
# Thread-246      File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 100, in l_data
#
#     self._target(*self._args, **self._kwargs)
#
#   File "/Users/mhamani/Desktop/network_project/class_sgw.py", line 80, in l_enodb
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#         self._target(*self._args, **self._kwargs)self._target(*self._args, **self._kwargs)    self._target(*self._args, **self._kwargs)      File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 35, in l_sgw
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 158, in send
# :
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# self.run()
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#
#
#
#   File "/Users/mhamani/Desktop/network_project/class_sgw.py", line 40, in l_mme
#   File "/Users/mhamani/Desktop/network_project/class_mme.py", line 34, in l_enodb
# Traceback (most recent call last):
#     self.run()
# self.enb_p=[i+7000 for i in self.enbs]
# NameError: name 'socket' is not defined
#         self._target(*self._args, **self._kwargs)
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 158, in send
# self._target(*self._args, **self._kwargs)  File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 129, in l_sig
#     self._target(*self._args, **self._kwargs)
# self._target(*self._args, **self._kwargs)          File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# self._target(*self._args, **self._kwargs)
#   File "/Users/mhamani/Desktop/network_project/class_sgw.py", line 80, in l_enodb
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 158, in send
#     self.run()
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#
# NameError: name 'socket' is not defined
# NameError
#     self._target(*self._args, **self._kwargs)self._target(*self._args, **self._kwargs)    def l_sig(self):
# self.run()
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# :   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 158, in send
#
#
# NameErrorname 'socket' is not defined  File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 73, in l_mme
#
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 73, in l_mme
#
#
# self.enb_p=[i+7000 for i in self.enbs]
# NameError: name 'socket' is not defined
# self.run()Exception in thread :         NameErrorThread-265    Exception in thread         data={}Exception in thread   File "/Users/mhamani/Desktop/network_project/class_mme.py", line 34, in l_enodb
# Exception in thread data={}
# NameError    Thread-271
# NameError:
#
#     Thread-267: :
#     Traceback (most recent call last):
#     name 'socket' is not definedself._target(*self._args, **self._kwargs)
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 73, in l_mme
# :
# Thread-269NameError    : name 'socket' is not definedself._target(*self._args, **self._kwargs):
# self._target(*self._args, **self._kwargs)
# name 'socket' is not defined
# :   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     :
# self._target(*self._args, **self._kwargs)data={}
# NameError: name 'pickle' is not defined
# name 'pickle' is not definedTraceback (most recent call last):
# Traceback (most recent call last):
#
# NameError
# : Traceback (most recent call last):
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()NameErrorException in thread
# Thread-268:
# Traceback (most recent call last):
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
# name 'socket' is not definedname 'socket' is not defined: name 'pickle' is not definedself.enb_p=[i+7000 for i in self.enbs]  File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#
# Exception in thread   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 35, in l_sgw
#
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 100, in l_data
# Thread-272NameError
# self.hfs=[]#handover ke omade ro befrestam jayi ke bayad
#
# :
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 73, in l_mme
#
# :
#     NameError
# self._target(*self._args, **self._kwargs)
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 129, in l_sig
# NameError: name 'socket' is not defined
# Traceback (most recent call last):
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# :   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
# NameError    self.run()
#
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# name 'socket' is not defined
# NameError    : name 'socket' is not defined
#
#       File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# data={}self._target(*self._args, **self._kwargs)
# NameError: name 'pickle' is not defined
# name 'socket' is not defined
#     self.run()
# :
#     NameError:     self.run()def l_sig(self):
# NameError: name 'socket' is not defined
# self.enb_p=[i+7000 for i in self.enbs]name 'socket' is not definedNameError    :             self._target(*self._args, **self._kwargs)self.run()name 'socket' is not defined
#
#
# self.run()
#
#
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
# self._target(*self._args, **self._kwargs)
#     NameError:   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 129, in l_sig
#
# self.run()
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 129, in l_sig
#
# name 'socket' is not definedNameError: name 'socket' is not defined
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#
#
# name 'socket' is not defined  File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 100, in l_data
#
# NameError    self._target(*self._args, **self._kwargs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <cell line: 15>()
#      13 network.add_user(2,[(1,0),(0,1),(3,2)],[0.5,2],[0.1,0.7,0.3,0.4])
#      14 network.connection_request(0,1,'1.txt')
# ---> 15 network.connection_request(2,3,'2.txt')
#      17 network.run()
#
# File ~/Desktop/network_project/class_network.py:56, in Network.connection_request(self, sender_id, receiver_id, file_name)
#      53 k2=[(item[0],item[1],item[2],self.n1) for item in self.user if receiver_id==item[0]]
#      55 s1=user_f(k1[0][0],k1[0][1],k1[0][2],k1[0][3],k1[0][4],k1[0][5],file_name)
# ---> 56 s2=user_g(k2[0][0],k2[0][1],k2[0][2],k2[0][3])
#      59 t1=threading.Thread(target=s1.run1)
#      60 t2=threading.Thread(target=s2.run1)
#
# IndexError: list index out of range
#   File "/Users/mhamani/Desktop/network_project/class_users.py", line 150, in send_loc1
# :     def l_sig(self):name 'socket' is not defined
#     self.run()    self._target(*self._args, **self._kwargs)NameError
#   File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#
#   File "/Users/mhamani/Desktop/network_project/class_eNodeB.py", line 100, in l_data
# :       File "/Users/mhamani/miniconda3/lib/python3.8/threading.py", line 870, in run
#
#         name 'socket' is not defined    self._target(*self._args, **self._kwargs)    self._target(*self._args, **self._kwargs)
#
# self._target(*self._args, **self._kwargs)data={};
#   File "/Users/mhamani/Desktop/network_project/class_users.py", line 256, in l_sig
# NameError
# :
#   File "/Users/mhamani/Desktop/network_project/class_users.py", line 381, in send_loc1
#   File "/Users/mhamani/Desktop/network_project/class_users.py", line 68, in l_data
# name 'pickle' is not defined
#         self._target(*self._args, **self._kwargs)self._target(*self._args, **self._kwargs)
#
# NameError:
#   File "/Users/mhamani/Desktop/network_project/class_users.py", line 295, in l_data
# name 'socket' is not defineddef l_sig(self):
#   File "/Users/mhamani/Desktop/network_project/class_users.py", line 30, in l_sig
#
# NameError
# : NameError: name 'socket' is not defined
#     name 'socket' is not defined
#     return
#
# NameError: name 'socket' is not defined
#
# NameError: NameError
# self.p_data=[i+6000 for i in self.enodbs]NameError: name 'time' is not defined
# name 'socket' is not defined: name 'socket' is not defined
#
# NameError: name 'socket' is not defined
#
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out

# %%
from class_eNodeB import eNodeB
cc = eNodeB(10, [0,1], 3)

# %%
from class_mme import MME
mmeee = MME(10, 10)

# %%
from class_sgw import SGW
sgww = SGW(10, 10)

# %%
from class_users import user_g, user_f
usergg = user_g(10, [1,2,23,4,5], 2, 10)
userff = user_f(10, [1,2,4,5,6], 2, 20, 10, 10, '1.txt')
